# %%
import sys
sys.path.append('../')
from dataset import *
from data_aug import *
import tensorflow as tf
from comparison_model import *
from utils import *
from ranking_model import *

import random
import numpy as np
from tensorflow.keras.applications import VGG19
from tensorflow.keras.layers import Input, Dense, Flatten, BatchNormalization, Dropout, Subtract, Activation
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from tensorflow.keras.callbacks import EarlyStopping

# %%
image1_array, image2_array, labels = load_data("../Mapillary/mapillary_training_dataaug_contrast/")

# %%
batch_size = 64

train_generator, valid_generator, test_generator, train_size, valid_size = prepare_dataset_generators(image1_array, image2_array, labels, batch_size, "comparison")

train_steps_per_epoch = train_size // batch_size
valid_steps_per_epoch = valid_size // batch_size

# %% [markdown]
# # Best comparison model from streetview trained on mapillary data with data augmentation using constrast

# %%
def comparison_siamese_model(input_shape):
    """Create a siamese model for image comparison using VGG19 as base model.

    Args:
        input_shape (tuple): Shape of the input images.
    Returns:
        keras.models.Model: The compiled siamese model.
    """
    base_model = VGG19(weights='imagenet', include_top=False, input_shape=input_shape)
    for layer in base_model.layers[:-4]:
        layer.trainable=False

    # Create inputs for pairs of images
    input_1 = Input(shape=input_shape)
    input_2 = Input(shape=input_shape)

    # Get embeddings of the images using the shared VGG19 model
    output_1 = base_model(input_1)
    output_2 = base_model(input_2)

    concat = concatenate([output_1, output_2])

    # Classification layer to predict similarity
    flatten = Flatten()(concat)
    x = Conv2D(32, (3, 3), activation="tanh", padding='same')(concat)
    x = Dropout(0.3)(x)
    x = Conv2D(32, (3, 3), activation="tanh", padding='same')(x)
    x = Dropout(0.3)(x)
    x = Flatten()(x)
    output = Dense(2, activation='sigmoid')(x)

    # Create the complete siamese model
    siamese_model = Model(inputs=[input_1, input_2], outputs=output)

    # Compile the model with the provided hyperparameters
    siamese_model.compile(loss="binary_crossentropy", optimizer=Adam(learning_rate=1e-05, decay=0.001), metrics=['accuracy'])

    # Print model summary
    siamese_model.summary()

    return siamese_model

siamese_model = comparison_siamese_model((224,224,3))

siamese_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# vgg19 (Functional)              (None, 7, 7, 512)    20024384    input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 7, 7, 1024)   0           vgg19[0][0]
#                                                                  vgg19[1][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 7, 7, 32)     294944      concatenate[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 7, 7, 32)     0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 7, 7, 32)     9248        dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 7, 7, 32)     0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 1568)         0           dropout_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 2)            3138        flatten_1[0][0]
# ==================================================================================================
# Total params: 20,331,714
# Trainable params: 7,386,754
# Non-trainable params: 12,944,960
# __________________________________________________________________________________________________
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# vgg19 (Functional)              (None, 7, 7, 512)    20024384    input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 7, 7, 1024)   0           vgg19[0][0]
#                                                                  vgg19[1][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 7, 7, 32)     294944      concatenate[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 7, 7, 32)     0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 7, 7, 32)     9248        dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 7, 7, 32)     0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 1568)         0           dropout_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 2)            3138        flatten_1[0][0]
# ==================================================================================================
# Total params: 20,331,714
# Trainable params: 7,386,754
# Non-trainable params: 12,944,960
# __________________________________________________________________________________________________

# %%
history = siamese_model.fit(train_generator,
          steps_per_epoch=train_steps_per_epoch,
          epochs=50,
          validation_data=valid_generator,
          validation_steps=valid_steps_per_epoch)
# Out:
# Epoch 1/50
# 171/171 [==============================] - 120s 597ms/step - loss: 0.6164 - accuracy: 0.6734 - val_loss: 0.4920 - val_accuracy: 0.7656
# Epoch 2/50
# 171/171 [==============================] - 84s 486ms/step - loss: 0.5018 - accuracy: 0.7723 - val_loss: 0.4543 - val_accuracy: 0.7887
# Epoch 3/50
# 171/171 [==============================] - 83s 484ms/step - loss: 0.4663 - accuracy: 0.7906 - val_loss: 0.4317 - val_accuracy: 0.8018
# Epoch 4/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.4397 - accuracy: 0.8033 - val_loss: 0.4130 - val_accuracy: 0.8125
# Epoch 5/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.4176 - accuracy: 0.8190 - val_loss: 0.3997 - val_accuracy: 0.8243
# Epoch 6/50
# 171/171 [==============================] - 83s 484ms/step - loss: 0.3969 - accuracy: 0.8337 - val_loss: 0.3827 - val_accuracy: 0.8320
# Epoch 7/50
# 171/171 [==============================] - 83s 484ms/step - loss: 0.3818 - accuracy: 0.8404 - val_loss: 0.3688 - val_accuracy: 0.8413
# Epoch 8/50
# 171/171 [==============================] - 83s 484ms/step - loss: 0.3643 - accuracy: 0.8528 - val_loss: 0.3558 - val_accuracy: 0.8528
# Epoch 9/50
# 171/171 [==============================] - 83s 484ms/step - loss: 0.3476 - accuracy: 0.8647 - val_loss: 0.3438 - val_accuracy: 0.8583
# Epoch 10/50
# 171/171 [==============================] - 83s 484ms/step - loss: 0.3371 - accuracy: 0.8720 - val_loss: 0.3319 - val_accuracy: 0.8714
# Epoch 11/50
# 171/171 [==============================] - 83s 484ms/step - loss: 0.3238 - accuracy: 0.8798 - val_loss: 0.3211 - val_accuracy: 0.8766
# Epoch 12/50
# 171/171 [==============================] - 83s 483ms/step - loss: 0.3105 - accuracy: 0.8876 - val_loss: 0.3110 - val_accuracy: 0.8816
# Epoch 13/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.2992 - accuracy: 0.8953 - val_loss: 0.3010 - val_accuracy: 0.8871
# Epoch 14/50
# 171/171 [==============================] - 83s 484ms/step - loss: 0.2880 - accuracy: 0.9000 - val_loss: 0.2940 - val_accuracy: 0.8884
# Epoch 15/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.2765 - accuracy: 0.9083 - val_loss: 0.2830 - val_accuracy: 0.8956
# Epoch 16/50
# 171/171 [==============================] - 83s 484ms/step - loss: 0.2675 - accuracy: 0.9107 - val_loss: 0.2740 - val_accuracy: 0.8999
# Epoch 17/50
# 171/171 [==============================] - 83s 484ms/step - loss: 0.2576 - accuracy: 0.9180 - val_loss: 0.2674 - val_accuracy: 0.9032
# Epoch 18/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.2500 - accuracy: 0.9185 - val_loss: 0.2577 - val_accuracy: 0.9090
# Epoch 19/50
# 171/171 [==============================] - 83s 484ms/step - loss: 0.2419 - accuracy: 0.9233 - val_loss: 0.2503 - val_accuracy: 0.9126
# Epoch 20/50
# 171/171 [==============================] - 83s 484ms/step - loss: 0.2341 - accuracy: 0.9275 - val_loss: 0.2433 - val_accuracy: 0.9147
# Epoch 21/50
# 171/171 [==============================] - 83s 483ms/step - loss: 0.2249 - accuracy: 0.9347 - val_loss: 0.2366 - val_accuracy: 0.9221
# Epoch 22/50
# 171/171 [==============================] - 83s 484ms/step - loss: 0.2191 - accuracy: 0.9339 - val_loss: 0.2312 - val_accuracy: 0.9238
# Epoch 23/50
# 171/171 [==============================] - 83s 484ms/step - loss: 0.2109 - accuracy: 0.9397 - val_loss: 0.2236 - val_accuracy: 0.9271
# Epoch 24/50
# 171/171 [==============================] - 83s 484ms/step - loss: 0.2051 - accuracy: 0.9439 - val_loss: 0.2172 - val_accuracy: 0.9290
# Epoch 25/50
# 171/171 [==============================] - 83s 484ms/step - loss: 0.1957 - accuracy: 0.9455 - val_loss: 0.2121 - val_accuracy: 0.9317
# Epoch 26/50
# 171/171 [==============================] - 83s 484ms/step - loss: 0.1933 - accuracy: 0.9468 - val_loss: 0.2054 - val_accuracy: 0.9370
# Epoch 27/50
# 171/171 [==============================] - 83s 483ms/step - loss: 0.1854 - accuracy: 0.9510 - val_loss: 0.1997 - val_accuracy: 0.9370
# Epoch 28/50
# 171/171 [==============================] - 83s 484ms/step - loss: 0.1817 - accuracy: 0.9521 - val_loss: 0.1948 - val_accuracy: 0.9386
# Epoch 29/50
# 171/171 [==============================] - 83s 483ms/step - loss: 0.1741 - accuracy: 0.9572 - val_loss: 0.1935 - val_accuracy: 0.9378
# Epoch 30/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.1685 - accuracy: 0.9591 - val_loss: 0.1878 - val_accuracy: 0.9413
# Epoch 31/50
# 171/171 [==============================] - 83s 484ms/step - loss: 0.1679 - accuracy: 0.9569 - val_loss: 0.1795 - val_accuracy: 0.9479
# Epoch 32/50
# 171/171 [==============================] - 83s 484ms/step - loss: 0.1579 - accuracy: 0.9616 - val_loss: 0.1748 - val_accuracy: 0.9490
# Epoch 33/50
# 171/171 [==============================] - 83s 484ms/step - loss: 0.1538 - accuracy: 0.9653 - val_loss: 0.1704 - val_accuracy: 0.9504
# Epoch 34/50
# 171/171 [==============================] - 83s 484ms/step - loss: 0.1509 - accuracy: 0.9659 - val_loss: 0.1667 - val_accuracy: 0.9518
# Epoch 35/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.1456 - accuracy: 0.9680 - val_loss: 0.1621 - val_accuracy: 0.9537
# Epoch 36/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.1431 - accuracy: 0.9680 - val_loss: 0.1579 - val_accuracy: 0.9559
# Epoch 37/50
# 171/171 [==============================] - 83s 484ms/step - loss: 0.1350 - accuracy: 0.9718 - val_loss: 0.1533 - val_accuracy: 0.9613
# Epoch 38/50
# 171/171 [==============================] - 83s 484ms/step - loss: 0.1345 - accuracy: 0.9715 - val_loss: 0.1501 - val_accuracy: 0.9605
# Epoch 39/50
# 171/171 [==============================] - 83s 484ms/step - loss: 0.1286 - accuracy: 0.9729 - val_loss: 0.1463 - val_accuracy: 0.9613
# Epoch 40/50
# 171/171 [==============================] - 83s 484ms/step - loss: 0.1265 - accuracy: 0.9742 - val_loss: 0.1428 - val_accuracy: 0.9630
# Epoch 41/50
# 171/171 [==============================] - 83s 484ms/step - loss: 0.1235 - accuracy: 0.9763 - val_loss: 0.1385 - val_accuracy: 0.9660
# Epoch 42/50
# 171/171 [==============================] - 83s 484ms/step - loss: 0.1180 - accuracy: 0.9780 - val_loss: 0.1356 - val_accuracy: 0.9660
# Epoch 43/50
# 171/171 [==============================] - 83s 484ms/step - loss: 0.1147 - accuracy: 0.9791 - val_loss: 0.1317 - val_accuracy: 0.9688
# Epoch 44/50
# 171/171 [==============================] - 83s 484ms/step - loss: 0.1122 - accuracy: 0.9789 - val_loss: 0.1284 - val_accuracy: 0.9693
# Epoch 45/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.1109 - accuracy: 0.9798 - val_loss: 0.1263 - val_accuracy: 0.9698
# Epoch 46/50
# 171/171 [==============================] - 83s 484ms/step - loss: 0.1078 - accuracy: 0.9791 - val_loss: 0.1234 - val_accuracy: 0.9701
# Epoch 47/50
# 171/171 [==============================] - 83s 484ms/step - loss: 0.1030 - accuracy: 0.9828 - val_loss: 0.1200 - val_accuracy: 0.9729
# Epoch 48/50
# 171/171 [==============================] - 83s 484ms/step - loss: 0.1021 - accuracy: 0.9825 - val_loss: 0.1163 - val_accuracy: 0.9726
# Epoch 49/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.0957 - accuracy: 0.9840 - val_loss: 0.1149 - val_accuracy: 0.9720
# Epoch 50/50
# 171/171 [==============================] - 83s 484ms/step - loss: 0.0962 - accuracy: 0.9844 - val_loss: 0.1119 - val_accuracy: 0.9731

# %%
plot_accuracy(history)
plot_loss(history)

siamese_model.save("comparison.h5")

# %%
siamese_model.load_weights("../Result/Mapillary_Results/Best_ComparisonModel_From_Streetview_Trained_On_Mapillary_DataAug_Contrast/comparison.h5")
siamese_model.evaluate(test_generator, steps=valid_steps_per_epoch)
# Out:
# 57/57 [==============================] - 35s 326ms/step - loss: 0.0952 - accuracy: 0.9830
# [0.09519371390342712, 0.9830043911933899]

# %% [markdown]
# # Best ranking model from streetview trained on mapillary data with data augmentation using constrast

# %%
batch_size = 64

train_generator, valid_generator, test_generator, train_size, valid_size = prepare_dataset_generators(image1_array, image2_array, labels, batch_size, "ranking")

train_steps_per_epoch = train_size // batch_size
valid_steps_per_epoch = valid_size // batch_size

# %%
def create_ranking_network(img_size):
    """
    Create ranking network which give a score to an image.

    :param img_size: size of input images during training
    :type img_size: tuple(int)
    :return: ranking network model
    :rtype: keras.Model
    """
    # Create feature extractor from VGG19
    feature_extractor = VGG19(weights="imagenet", include_top=False, input_shape=(img_size, img_size, 3))
    for layer in feature_extractor.layers[:-4]:
        layer.trainable = False

    # Add dense layers on top of the feature extractor
    inp = Input(shape=(img_size, img_size, 3), name='input_image')
    base = feature_extractor(inp)
    base = Flatten(name='Flatten')(base)

    # Block 1
    base = Dense(32, activation='sigmoid', name='Dense_1')(base)
    base = BatchNormalization(name='BN1')(base)
    base = Dropout(0.2, name='Drop_1')(base)

    # Block 2
    base = Dense(32, activation='sigmoid', name='Dense_2')(base)
    base = BatchNormalization(name='BN2')(base)
    base = Dropout(0.2, name='Drop_2')(base)

    # Final dense
    base = Dense(1, name="Dense_Output")(base)
    base_network = Model(inp, base, name='Scoring_model')
    return base_network


def create_meta_network(img_size, weights=None):
    """
    Create meta network which is used to to teach the ranking network.

    :param img_size: dimension of input images during training.
    :type img_size: tuple(int)
    :param weights: path to the weights use for initialization
    :type weights: str
    :return: meta network model
    :rtype: keras.Model
    """

    # Create the two input branches
    input_left = Input(shape=(img_size, img_size, 3), name='left_input')
    input_right = Input(shape=(img_size, img_size, 3), name='right_input')
    base_network = create_ranking_network(img_size)
    left_score = base_network(input_left)
    right_score = base_network(input_right)

    # Subtract scores
    diff = Subtract()([left_score, right_score])

    # Pass difference through sigmoid function.
    prob = Activation("sigmoid", name="Activation_sigmoid")(diff)
    model = Model(inputs=[input_left, input_right], outputs= prob, name="Meta_Model")

    if weights:
        print('Loading weights ...')
        model.load_weights(weights)

    model.compile(optimizer=RMSprop(learning_rate=0.0001, decay=1e-05), loss="binary_crossentropy", metrics=['accuracy'])

    return model

meta_model = create_meta_network(224)

# %%
history = meta_model.fit(train_generator,
          steps_per_epoch=train_steps_per_epoch,
          epochs=50,
          validation_data=valid_generator,
          validation_steps=valid_steps_per_epoch)

meta_model.save("meta_model_wieght.h5")
ranking_model = meta_model.get_layer('Scoring_model')
ranking_model.save_weights('ranking_model_weights.h5')
plot_loss(history)
plot_accuracy(history)
# Out:
# Epoch 1/50
# 171/171 [==============================] - 149s 765ms/step - loss: 0.5511 - accuracy: 0.7469 - val_loss: 0.4414 - val_accuracy: 0.8150
# Epoch 2/50
# 171/171 [==============================] - 86s 495ms/step - loss: 0.4281 - accuracy: 0.8112 - val_loss: 0.3217 - val_accuracy: 0.8616
# Epoch 3/50
# 171/171 [==============================] - 83s 486ms/step - loss: 0.3398 - accuracy: 0.8563 - val_loss: 0.2239 - val_accuracy: 0.9106
# Epoch 4/50
# 171/171 [==============================] - 83s 486ms/step - loss: 0.2464 - accuracy: 0.9021 - val_loss: 0.1912 - val_accuracy: 0.9290
# Epoch 5/50
# 171/171 [==============================] - 83s 486ms/step - loss: 0.1888 - accuracy: 0.9255 - val_loss: 0.1273 - val_accuracy: 0.9515
# Epoch 6/50
# 171/171 [==============================] - 83s 487ms/step - loss: 0.1472 - accuracy: 0.9436 - val_loss: 0.1137 - val_accuracy: 0.9592
# Epoch 7/50
# 171/171 [==============================] - 83s 486ms/step - loss: 0.1239 - accuracy: 0.9541 - val_loss: 0.0815 - val_accuracy: 0.9737
# Epoch 8/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.1073 - accuracy: 0.9613 - val_loss: 0.0842 - val_accuracy: 0.9762
# Epoch 9/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.0941 - accuracy: 0.9654 - val_loss: 0.0716 - val_accuracy: 0.9759
# Epoch 10/50
# 171/171 [==============================] - 83s 486ms/step - loss: 0.0847 - accuracy: 0.9691 - val_loss: 0.0628 - val_accuracy: 0.9775
# Epoch 11/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.0764 - accuracy: 0.9710 - val_loss: 0.0563 - val_accuracy: 0.9805
# Epoch 12/50
# 171/171 [==============================] - 83s 486ms/step - loss: 0.0722 - accuracy: 0.9747 - val_loss: 0.0549 - val_accuracy: 0.9808
# Epoch 13/50
# 171/171 [==============================] - 83s 486ms/step - loss: 0.0611 - accuracy: 0.9784 - val_loss: 0.0537 - val_accuracy: 0.9805
# Epoch 14/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.0569 - accuracy: 0.9800 - val_loss: 0.0396 - val_accuracy: 0.9879
# Epoch 15/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.0519 - accuracy: 0.9817 - val_loss: 0.0414 - val_accuracy: 0.9836
# Epoch 16/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.0507 - accuracy: 0.9823 - val_loss: 0.0337 - val_accuracy: 0.9885
# Epoch 17/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.0480 - accuracy: 0.9826 - val_loss: 0.0379 - val_accuracy: 0.9868
# Epoch 18/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.0407 - accuracy: 0.9861 - val_loss: 0.0259 - val_accuracy: 0.9923
# Epoch 19/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.0434 - accuracy: 0.9847 - val_loss: 0.0248 - val_accuracy: 0.9929
# Epoch 20/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.0387 - accuracy: 0.9865 - val_loss: 0.0309 - val_accuracy: 0.9904
# Epoch 21/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.0362 - accuracy: 0.9880 - val_loss: 0.0304 - val_accuracy: 0.9901
# Epoch 22/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.0340 - accuracy: 0.9874 - val_loss: 0.0273 - val_accuracy: 0.9923
# Epoch 23/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.0322 - accuracy: 0.9889 - val_loss: 0.0309 - val_accuracy: 0.9893
# Epoch 24/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.0309 - accuracy: 0.9888 - val_loss: 0.0256 - val_accuracy: 0.9918
# Epoch 25/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.0312 - accuracy: 0.9895 - val_loss: 0.0198 - val_accuracy: 0.9937
# Epoch 26/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.0290 - accuracy: 0.9900 - val_loss: 0.0217 - val_accuracy: 0.9934
# Epoch 27/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.0245 - accuracy: 0.9918 - val_loss: 0.0185 - val_accuracy: 0.9942
# Epoch 28/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.0321 - accuracy: 0.9893 - val_loss: 0.0175 - val_accuracy: 0.9951
# Epoch 29/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.0302 - accuracy: 0.9891 - val_loss: 0.0155 - val_accuracy: 0.9948
# Epoch 30/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.0286 - accuracy: 0.9898 - val_loss: 0.0162 - val_accuracy: 0.9940
# Epoch 31/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.0218 - accuracy: 0.9923 - val_loss: 0.0142 - val_accuracy: 0.9967
# Epoch 32/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.0221 - accuracy: 0.9920 - val_loss: 0.0210 - val_accuracy: 0.9918
# Epoch 33/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.0231 - accuracy: 0.9921 - val_loss: 0.0150 - val_accuracy: 0.9945
# Epoch 34/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.0220 - accuracy: 0.9929 - val_loss: 0.0184 - val_accuracy: 0.9945
# Epoch 35/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.0265 - accuracy: 0.9904 - val_loss: 0.0221 - val_accuracy: 0.9931
# Epoch 36/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.0236 - accuracy: 0.9917 - val_loss: 0.0139 - val_accuracy: 0.9956
# Epoch 37/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.0215 - accuracy: 0.9928 - val_loss: 0.0135 - val_accuracy: 0.9956
# Epoch 38/50
# 171/171 [==============================] - 83s 486ms/step - loss: 0.0211 - accuracy: 0.9929 - val_loss: 0.0134 - val_accuracy: 0.9964
# Epoch 39/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.0203 - accuracy: 0.9933 - val_loss: 0.0115 - val_accuracy: 0.9975
# Epoch 40/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.0220 - accuracy: 0.9927 - val_loss: 0.0140 - val_accuracy: 0.9959
# Epoch 41/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.0199 - accuracy: 0.9928 - val_loss: 0.0097 - val_accuracy: 0.9964
# Epoch 42/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.0150 - accuracy: 0.9956 - val_loss: 0.0105 - val_accuracy: 0.9967
# Epoch 43/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.0224 - accuracy: 0.9927 - val_loss: 0.0134 - val_accuracy: 0.9948
# Epoch 44/50
# 171/171 [==============================] - 83s 486ms/step - loss: 0.0206 - accuracy: 0.9927 - val_loss: 0.0149 - val_accuracy: 0.9945
# Epoch 45/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.0212 - accuracy: 0.9933 - val_loss: 0.0089 - val_accuracy: 0.9978
# Epoch 46/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.0166 - accuracy: 0.9942 - val_loss: 0.0068 - val_accuracy: 0.9981
# Epoch 47/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.0160 - accuracy: 0.9943 - val_loss: 0.0126 - val_accuracy: 0.9967
# Epoch 48/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.0190 - accuracy: 0.9943 - val_loss: 0.0100 - val_accuracy: 0.9973
# Epoch 49/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.0172 - accuracy: 0.9944 - val_loss: 0.0091 - val_accuracy: 0.9964
# Epoch 50/50
# 171/171 [==============================] - 83s 486ms/step - loss: 0.0177 - accuracy: 0.9938 - val_loss: 0.0091 - val_accuracy: 0.9970
# c:\anaconda\envs\tqdm\lib\site-packages\tensorflow\python\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '

# %%
meta_model.evaluate(test_generator, steps=valid_steps_per_epoch)
# Out:
# 57/57 [==============================] - 23s 396ms/step - loss: 0.0030 - accuracy: 0.9995
# [0.0029657958075404167, 0.999451756477356]
