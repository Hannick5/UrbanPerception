# %%
import tensorflow as tf
from tensorflow import keras
from utils import *

# %%
model = tf.keras.models.load_model('Result\Streetview_Result\Comparison_handpicked_DataAug\handpicked_siamese_modle.h5')

# %%
model.summary()
# Out:
# Model: "model_62"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_188 (InputLayer)          [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# input_189 (InputLayer)          [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# vgg19 (Functional)              (None, 7, 7, 512)    20024384    input_188[0][0]
#                                                                  input_189[0][0]
# __________________________________________________________________________________________________
# concatenate_62 (Concatenate)    (None, 7, 7, 1024)   0           vgg19[0][0]
#                                                                  vgg19[1][0]
# ...

# %%
from dataset import *
import cv2
X_pred = prepare_prediction_siamese("data/question_1/ForPrediction/*/*", shape = 224)
# Out:
# Processing Images: 100%|██████████| 26088/26088 [01:37<00:00, 268.21image/s]

# %%
# Sélectionnez un couple d'images
index = 0  # Indice de l'image à sélectionner
image1 = X_pred[0][index]
image2 = X_pred[1][index]

im = generate_saliency_map(model,image1,image2)
plt.imshow(im)

# %%
plt.imshow(image1)
