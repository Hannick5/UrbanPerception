# %%
import sys
sys.path.append('../')
from dataset import *
from data_aug import *
import tensorflow as tf
from comparison_model import *
from utils import *
from ranking_model import *

import random
import numpy as np
from tensorflow.keras.applications import VGG19
from tensorflow.keras.layers import Input, Dense, Flatten, BatchNormalization, Dropout, Subtract, Activation
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# # Handpicked Comparison model trained on Streetview data using contrast data augmentation

# %%
image1_array, image2_array, labels = load_data("../data/question_1/Streetview_dataaug/")

# %%
batch_size = 64

train_generator, valid_generator, test_generator, train_size, valid_size = prepare_dataset_generators(image1_array, image2_array, labels, batch_size, "comparison")

train_steps_per_epoch = train_size // batch_size
valid_steps_per_epoch = valid_size // batch_size

# %%
def comparison_siamese_model(input_shape):
    """Create a siamese model for image comparison using VGG19 as base model.

    Args:
        input_shape (tuple): Shape of the input images.
    Returns:
        keras.models.Model: The compiled siamese model.
    """
    base_model = VGG19(weights='imagenet', include_top=False, input_shape=input_shape)
    for layer in base_model.layers[:-4]:
        layer.trainable=False

    # Create inputs for pairs of images
    input_1 = Input(shape=input_shape)
    input_2 = Input(shape=input_shape)

    # Get embeddings of the images using the shared VGG19 model
    output_1 = base_model(input_1)
    output_2 = base_model(input_2)

    concat = concatenate([output_1, output_2])

    # Classification layer to predict similarity
    flatten = Flatten()(concat)
    x = Conv2D(32, (3, 3), activation="tanh", padding='same')(concat)
    x = Dropout(0.3)(x)
    x = Conv2D(32, (3, 3), activation="tanh", padding='same')(x)
    x = Dropout(0.3)(x)
    x = Flatten()(x)
    output = Dense(2, activation='sigmoid')(x)

    # Create the complete siamese model
    siamese_model = Model(inputs=[input_1, input_2], outputs=output)

    # Compile the model with the provided hyperparameters
    siamese_model.compile(loss="binary_crossentropy", optimizer=Adam(learning_rate=1e-05, decay=0.001), metrics=['accuracy'])

    # Print model summary
    siamese_model.summary()

    return siamese_model

siamese_model = comparison_siamese_model((224,224,3))

siamese_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# vgg19 (Functional)              (None, 7, 7, 512)    20024384    input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 7, 7, 1024)   0           vgg19[0][0]
#                                                                  vgg19[1][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 7, 7, 32)     294944      concatenate[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 7, 7, 32)     0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 7, 7, 32)     9248        dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 7, 7, 32)     0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 1568)         0           dropout_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 2)            3138        flatten_1[0][0]
# ==================================================================================================
# Total params: 20,331,714
# Trainable params: 7,386,754
# Non-trainable params: 12,944,960
# __________________________________________________________________________________________________
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# vgg19 (Functional)              (None, 7, 7, 512)    20024384    input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 7, 7, 1024)   0           vgg19[0][0]
#                                                                  vgg19[1][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 7, 7, 32)     294944      concatenate[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 7, 7, 32)     0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 7, 7, 32)     9248        dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 7, 7, 32)     0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 1568)         0           dropout_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 2)            3138        flatten_1[0][0]
# ==================================================================================================
# Total params: 20,331,714
# Trainable params: 7,386,754
# Non-trainable params: 12,944,960
# __________________________________________________________________________________________________

# %%
history = siamese_model.fit(train_generator,
          steps_per_epoch=train_steps_per_epoch,
          epochs=50,
          validation_data=valid_generator,
          validation_steps=valid_steps_per_epoch)
# Out:
# Epoch 1/50
# 171/171 [==============================] - 199s 1s/step - loss: 0.5536 - accuracy: 0.7232 - val_loss: 0.4135 - val_accuracy: 0.8177
# Epoch 2/50
# 171/171 [==============================] - 87s 499ms/step - loss: 0.4094 - accuracy: 0.8230 - val_loss: 0.3657 - val_accuracy: 0.8402
# Epoch 3/50
# 171/171 [==============================] - 83s 487ms/step - loss: 0.3646 - accuracy: 0.8468 - val_loss: 0.3433 - val_accuracy: 0.8512
# Epoch 4/50
# 171/171 [==============================] - 83s 486ms/step - loss: 0.3415 - accuracy: 0.8578 - val_loss: 0.3223 - val_accuracy: 0.8621
# Epoch 5/50
# 171/171 [==============================] - 83s 486ms/step - loss: 0.3181 - accuracy: 0.8711 - val_loss: 0.3050 - val_accuracy: 0.8758
# Epoch 6/50
# 171/171 [==============================] - 83s 488ms/step - loss: 0.2985 - accuracy: 0.8825 - val_loss: 0.2926 - val_accuracy: 0.8843
# Epoch 7/50
# 171/171 [==============================] - 83s 486ms/step - loss: 0.2796 - accuracy: 0.8952 - val_loss: 0.2775 - val_accuracy: 0.8860
# Epoch 8/50
# 171/171 [==============================] - 83s 487ms/step - loss: 0.2679 - accuracy: 0.9011 - val_loss: 0.2672 - val_accuracy: 0.8978
# Epoch 9/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.2523 - accuracy: 0.9092 - val_loss: 0.2535 - val_accuracy: 0.9016
# Epoch 10/50
# 171/171 [==============================] - 83s 486ms/step - loss: 0.2398 - accuracy: 0.9163 - val_loss: 0.2429 - val_accuracy: 0.9090
# Epoch 11/50
# 171/171 [==============================] - 83s 486ms/step - loss: 0.2242 - accuracy: 0.9233 - val_loss: 0.2325 - val_accuracy: 0.9147
# Epoch 12/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.2181 - accuracy: 0.9284 - val_loss: 0.2219 - val_accuracy: 0.9200
# Epoch 13/50
# 171/171 [==============================] - 83s 486ms/step - loss: 0.2043 - accuracy: 0.9362 - val_loss: 0.2133 - val_accuracy: 0.9235
# Epoch 14/50
# 171/171 [==============================] - 83s 486ms/step - loss: 0.1944 - accuracy: 0.9403 - val_loss: 0.2082 - val_accuracy: 0.9285
# Epoch 15/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.1861 - accuracy: 0.9445 - val_loss: 0.1976 - val_accuracy: 0.9342
# Epoch 16/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.1762 - accuracy: 0.9500 - val_loss: 0.1917 - val_accuracy: 0.9356
# Epoch 17/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.1676 - accuracy: 0.9548 - val_loss: 0.1828 - val_accuracy: 0.9408
# Epoch 18/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.1609 - accuracy: 0.9555 - val_loss: 0.1764 - val_accuracy: 0.9416
# Epoch 19/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.1532 - accuracy: 0.9594 - val_loss: 0.1702 - val_accuracy: 0.9452
# Epoch 20/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.1469 - accuracy: 0.9614 - val_loss: 0.1667 - val_accuracy: 0.9452
# Epoch 21/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.1411 - accuracy: 0.9655 - val_loss: 0.1567 - val_accuracy: 0.9534
# Epoch 22/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.1347 - accuracy: 0.9658 - val_loss: 0.1513 - val_accuracy: 0.9583
# Epoch 23/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.1288 - accuracy: 0.9721 - val_loss: 0.1458 - val_accuracy: 0.9583
# Epoch 24/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.1250 - accuracy: 0.9707 - val_loss: 0.1412 - val_accuracy: 0.9600
# Epoch 25/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.1183 - accuracy: 0.9735 - val_loss: 0.1357 - val_accuracy: 0.9652
# Epoch 26/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.1133 - accuracy: 0.9740 - val_loss: 0.1309 - val_accuracy: 0.9660
# Epoch 27/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.1100 - accuracy: 0.9756 - val_loss: 0.1266 - val_accuracy: 0.9668
# Epoch 28/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.1044 - accuracy: 0.9788 - val_loss: 0.1227 - val_accuracy: 0.9682
# Epoch 29/50
# 171/171 [==============================] - 83s 486ms/step - loss: 0.0983 - accuracy: 0.9804 - val_loss: 0.1187 - val_accuracy: 0.9712
# Epoch 30/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.0935 - accuracy: 0.9829 - val_loss: 0.1162 - val_accuracy: 0.9685
# Epoch 31/50
# 171/171 [==============================] - 83s 486ms/step - loss: 0.0939 - accuracy: 0.9825 - val_loss: 0.1091 - val_accuracy: 0.9751
# Epoch 32/50
# 171/171 [==============================] - 83s 486ms/step - loss: 0.0875 - accuracy: 0.9844 - val_loss: 0.1075 - val_accuracy: 0.9745
# Epoch 33/50
# 171/171 [==============================] - 83s 486ms/step - loss: 0.0851 - accuracy: 0.9846 - val_loss: 0.1031 - val_accuracy: 0.9756
# Epoch 34/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.0837 - accuracy: 0.9859 - val_loss: 0.0988 - val_accuracy: 0.9781
# Epoch 35/50
# 171/171 [==============================] - 83s 486ms/step - loss: 0.0784 - accuracy: 0.9865 - val_loss: 0.0971 - val_accuracy: 0.9764
# Epoch 36/50
# 171/171 [==============================] - 83s 486ms/step - loss: 0.0758 - accuracy: 0.9882 - val_loss: 0.0934 - val_accuracy: 0.9786
# Epoch 37/50
# 171/171 [==============================] - 83s 486ms/step - loss: 0.0729 - accuracy: 0.9883 - val_loss: 0.0900 - val_accuracy: 0.9797
# Epoch 38/50
# 171/171 [==============================] - 83s 486ms/step - loss: 0.0709 - accuracy: 0.9885 - val_loss: 0.0863 - val_accuracy: 0.9811
# Epoch 39/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.0675 - accuracy: 0.9907 - val_loss: 0.0831 - val_accuracy: 0.9833
# Epoch 40/50
# 171/171 [==============================] - 83s 486ms/step - loss: 0.0636 - accuracy: 0.9912 - val_loss: 0.0814 - val_accuracy: 0.9814
# Epoch 41/50
# 171/171 [==============================] - 83s 486ms/step - loss: 0.0629 - accuracy: 0.9911 - val_loss: 0.0779 - val_accuracy: 0.9836
# Epoch 42/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.0585 - accuracy: 0.9925 - val_loss: 0.0756 - val_accuracy: 0.9838
# Epoch 43/50
# 171/171 [==============================] - 83s 486ms/step - loss: 0.0583 - accuracy: 0.9924 - val_loss: 0.0736 - val_accuracy: 0.9855
# Epoch 44/50
# 171/171 [==============================] - 83s 486ms/step - loss: 0.0553 - accuracy: 0.9930 - val_loss: 0.0703 - val_accuracy: 0.9863
# Epoch 45/50
# 171/171 [==============================] - 83s 485ms/step - loss: 0.0529 - accuracy: 0.9940 - val_loss: 0.0683 - val_accuracy: 0.9860
# Epoch 46/50
# 171/171 [==============================] - 83s 486ms/step - loss: 0.0506 - accuracy: 0.9938 - val_loss: 0.0662 - val_accuracy: 0.9868
# Epoch 47/50
# 171/171 [==============================] - 83s 487ms/step - loss: 0.0521 - accuracy: 0.9932 - val_loss: 0.0628 - val_accuracy: 0.9882
# Epoch 48/50
# 171/171 [==============================] - 83s 486ms/step - loss: 0.0478 - accuracy: 0.9950 - val_loss: 0.0624 - val_accuracy: 0.9877
# Epoch 49/50
# 171/171 [==============================] - 83s 486ms/step - loss: 0.0455 - accuracy: 0.9959 - val_loss: 0.0601 - val_accuracy: 0.9882
# Epoch 50/50
# 171/171 [==============================] - 83s 486ms/step - loss: 0.0439 - accuracy: 0.9955 - val_loss: 0.0571 - val_accuracy: 0.9893

# %%
plot_accuracy(history)
plot_loss(history)

siamese_model.save("comparison.h5")

# %%
siamese_model.load_weights("../Result/Streetview_Result/Comparison_Handpicked_DataAugmentation_With_contrast/comparison.h5")
siamese_model.evaluate(test_generator, steps=valid_steps_per_epoch)
# Out:
# 57/57 [==============================] - 34s 323ms/step - loss: 0.0462 - accuracy: 0.9951
# [0.0461895614862442, 0.9950658082962036]

# %% [markdown]
# # Handpicked Ranking model trained on Streetview data using contrast data augmentation

# %%
batch_size = 64

train_generator, valid_generator, test_generator, train_size, valid_size = prepare_dataset_generators(image1_array, image2_array, labels, batch_size, "ranking")

train_steps_per_epoch = train_size // batch_size
valid_steps_per_epoch = valid_size // batch_size

# %%
def create_ranking_network(img_size):
    """
    Create ranking network which give a score to an image.

    :param img_size: size of input images during training
    :type img_size: tuple(int)
    :return: ranking network model
    :rtype: keras.Model
    """
    # Create feature extractor from VGG19
    feature_extractor = VGG19(weights="imagenet", include_top=False, input_shape=(img_size, img_size, 3))
    for layer in feature_extractor.layers[:-4]:
        layer.trainable = False

    # Add dense layers on top of the feature extractor
    inp = Input(shape=(img_size, img_size, 3), name='input_image')
    base = feature_extractor(inp)
    base = Flatten(name='Flatten')(base)

    # Block 1
    base = Dense(32, activation='sigmoid', name='Dense_1')(base)
    base = BatchNormalization(name='BN1')(base)
    base = Dropout(0.2, name='Drop_1')(base)

    # Block 2
    base = Dense(32, activation='sigmoid', name='Dense_2')(base)
    base = BatchNormalization(name='BN2')(base)
    base = Dropout(0.2, name='Drop_2')(base)

    # Final dense
    base = Dense(1, name="Dense_Output")(base)
    base_network = Model(inp, base, name='Scoring_model')
    return base_network


def create_meta_network(img_size, weights=None):
    """
    Create meta network which is used to to teach the ranking network.

    :param img_size: dimension of input images during training.
    :type img_size: tuple(int)
    :param weights: path to the weights use for initialization
    :type weights: str
    :return: meta network model
    :rtype: keras.Model
    """

    # Create the two input branches
    input_left = Input(shape=(img_size, img_size, 3), name='left_input')
    input_right = Input(shape=(img_size, img_size, 3), name='right_input')
    base_network = create_ranking_network(img_size)
    left_score = base_network(input_left)
    right_score = base_network(input_right)

    # Subtract scores
    diff = Subtract()([left_score, right_score])

    # Pass difference through sigmoid function.
    prob = Activation("sigmoid", name="Activation_sigmoid")(diff)
    model = Model(inputs=[input_left, input_right], outputs= prob, name="Meta_Model")

    if weights:
        print('Loading weights ...')
        model.load_weights(weights)

    model.compile(optimizer=RMSprop(learning_rate=0.0001, decay=1e-05), loss="binary_crossentropy", metrics=['accuracy'])

    return model

meta_model = create_meta_network(224)

# %%
history = meta_model.fit(train_generator,
          steps_per_epoch=train_steps_per_epoch,
          epochs=50,
          validation_data=valid_generator,
          validation_steps=valid_steps_per_epoch)

meta_model.save("meta_model_wieght.h5")
ranking_model = meta_model.get_layer('Scoring_model')
ranking_model.save_weights('ranking_model_weights.h5')
plot_loss(history)
plot_accuracy(history)
# Out:
# Epoch 1/50
# 171/171 [==============================] - 215s 1s/step - loss: 0.4582 - accuracy: 0.8049 - val_loss: 0.3273 - val_accuracy: 0.8665
# Epoch 2/50
# 171/171 [==============================] - 92s 529ms/step - loss: 0.3432 - accuracy: 0.8540 - val_loss: 0.2469 - val_accuracy: 0.9030
# Epoch 3/50
# 171/171 [==============================] - 90s 528ms/step - loss: 0.2545 - accuracy: 0.8976 - val_loss: 0.1779 - val_accuracy: 0.9356
# Epoch 4/50
# 171/171 [==============================] - 90s 528ms/step - loss: 0.1923 - accuracy: 0.9259 - val_loss: 0.1282 - val_accuracy: 0.9548
# Epoch 5/50
# 171/171 [==============================] - 90s 528ms/step - loss: 0.1363 - accuracy: 0.9485 - val_loss: 0.1056 - val_accuracy: 0.9619
# Epoch 6/50
# 171/171 [==============================] - 90s 527ms/step - loss: 0.1082 - accuracy: 0.9605 - val_loss: 0.0793 - val_accuracy: 0.9742
# Epoch 7/50
# 171/171 [==============================] - 90s 527ms/step - loss: 0.0870 - accuracy: 0.9683 - val_loss: 0.0634 - val_accuracy: 0.9816
# Epoch 8/50
# 171/171 [==============================] - 90s 527ms/step - loss: 0.0726 - accuracy: 0.9735 - val_loss: 0.0455 - val_accuracy: 0.9868
# Epoch 9/50
# 171/171 [==============================] - 90s 526ms/step - loss: 0.0659 - accuracy: 0.9751 - val_loss: 0.0401 - val_accuracy: 0.9890
# Epoch 10/50
# 171/171 [==============================] - 90s 527ms/step - loss: 0.0586 - accuracy: 0.9785 - val_loss: 0.0394 - val_accuracy: 0.9893
# Epoch 11/50
# 171/171 [==============================] - 90s 527ms/step - loss: 0.0540 - accuracy: 0.9809 - val_loss: 0.0291 - val_accuracy: 0.9907
# Epoch 12/50
# 171/171 [==============================] - 90s 528ms/step - loss: 0.0439 - accuracy: 0.9853 - val_loss: 0.0247 - val_accuracy: 0.9929
# Epoch 13/50
# 171/171 [==============================] - 90s 527ms/step - loss: 0.0402 - accuracy: 0.9867 - val_loss: 0.0226 - val_accuracy: 0.9934
# Epoch 14/50
# 171/171 [==============================] - 90s 527ms/step - loss: 0.0349 - accuracy: 0.9883 - val_loss: 0.0252 - val_accuracy: 0.9915
# Epoch 15/50
# 171/171 [==============================] - 90s 527ms/step - loss: 0.0355 - accuracy: 0.9870 - val_loss: 0.0298 - val_accuracy: 0.9915
# Epoch 16/50
# 171/171 [==============================] - 90s 527ms/step - loss: 0.0372 - accuracy: 0.9866 - val_loss: 0.0192 - val_accuracy: 0.9951
# Epoch 17/50
# 171/171 [==============================] - 90s 526ms/step - loss: 0.0308 - accuracy: 0.9893 - val_loss: 0.0186 - val_accuracy: 0.9940
# Epoch 18/50
# 171/171 [==============================] - 90s 527ms/step - loss: 0.0293 - accuracy: 0.9903 - val_loss: 0.0123 - val_accuracy: 0.9967
# Epoch 19/50
# 171/171 [==============================] - 90s 527ms/step - loss: 0.0280 - accuracy: 0.9908 - val_loss: 0.0167 - val_accuracy: 0.9951
# Epoch 20/50
# 171/171 [==============================] - 90s 526ms/step - loss: 0.0269 - accuracy: 0.9906 - val_loss: 0.0131 - val_accuracy: 0.9962
# Epoch 21/50
# 171/171 [==============================] - 90s 527ms/step - loss: 0.0250 - accuracy: 0.9911 - val_loss: 0.0110 - val_accuracy: 0.9973
# Epoch 22/50
# 171/171 [==============================] - 90s 527ms/step - loss: 0.0239 - accuracy: 0.9923 - val_loss: 0.0228 - val_accuracy: 0.9945
# Epoch 23/50
# 171/171 [==============================] - 90s 526ms/step - loss: 0.0206 - accuracy: 0.9925 - val_loss: 0.0121 - val_accuracy: 0.9970
# Epoch 24/50
# 171/171 [==============================] - 90s 527ms/step - loss: 0.0213 - accuracy: 0.9931 - val_loss: 0.0152 - val_accuracy: 0.9948
# Epoch 25/50
# 171/171 [==============================] - 90s 527ms/step - loss: 0.0234 - accuracy: 0.9915 - val_loss: 0.0137 - val_accuracy: 0.9967
# Epoch 26/50
# 171/171 [==============================] - 90s 527ms/step - loss: 0.0226 - accuracy: 0.9936 - val_loss: 0.0125 - val_accuracy: 0.9962
# Epoch 27/50
# 171/171 [==============================] - 90s 527ms/step - loss: 0.0176 - accuracy: 0.9944 - val_loss: 0.0082 - val_accuracy: 0.9984
# Epoch 28/50
# 171/171 [==============================] - 90s 526ms/step - loss: 0.0200 - accuracy: 0.9940 - val_loss: 0.0132 - val_accuracy: 0.9962
# Epoch 29/50
# 171/171 [==============================] - 90s 528ms/step - loss: 0.0186 - accuracy: 0.9940 - val_loss: 0.0120 - val_accuracy: 0.9973
# Epoch 30/50
# 171/171 [==============================] - 90s 527ms/step - loss: 0.0175 - accuracy: 0.9944 - val_loss: 0.0069 - val_accuracy: 0.9989
# Epoch 31/50
# 171/171 [==============================] - 90s 526ms/step - loss: 0.0172 - accuracy: 0.9939 - val_loss: 0.0113 - val_accuracy: 0.9967
# Epoch 32/50
# 171/171 [==============================] - 90s 527ms/step - loss: 0.0164 - accuracy: 0.9950 - val_loss: 0.0076 - val_accuracy: 0.9973
# Epoch 33/50
# 171/171 [==============================] - 90s 526ms/step - loss: 0.0143 - accuracy: 0.9956 - val_loss: 0.0061 - val_accuracy: 0.9984
# Epoch 34/50
# 171/171 [==============================] - 90s 526ms/step - loss: 0.0147 - accuracy: 0.9952 - val_loss: 0.0045 - val_accuracy: 0.9989
# Epoch 35/50
# 171/171 [==============================] - 90s 526ms/step - loss: 0.0177 - accuracy: 0.9933 - val_loss: 0.0051 - val_accuracy: 0.9992
# Epoch 36/50
# 171/171 [==============================] - 90s 526ms/step - loss: 0.0102 - accuracy: 0.9972 - val_loss: 0.0049 - val_accuracy: 0.9984
# Epoch 37/50
# 171/171 [==============================] - 90s 526ms/step - loss: 0.0144 - accuracy: 0.9949 - val_loss: 0.0056 - val_accuracy: 0.9984
# Epoch 38/50
# 171/171 [==============================] - 90s 527ms/step - loss: 0.0128 - accuracy: 0.9957 - val_loss: 0.0056 - val_accuracy: 0.9981
# Epoch 39/50
# 171/171 [==============================] - 90s 527ms/step - loss: 0.0127 - accuracy: 0.9954 - val_loss: 0.0063 - val_accuracy: 0.9975
# Epoch 40/50
# 171/171 [==============================] - 90s 527ms/step - loss: 0.0129 - accuracy: 0.9959 - val_loss: 0.0075 - val_accuracy: 0.9978
# Epoch 41/50
# 171/171 [==============================] - 90s 527ms/step - loss: 0.0149 - accuracy: 0.9949 - val_loss: 0.0049 - val_accuracy: 0.9986
# Epoch 42/50
# 171/171 [==============================] - 90s 527ms/step - loss: 0.0149 - accuracy: 0.9952 - val_loss: 0.0045 - val_accuracy: 0.9986
# Epoch 43/50
# 171/171 [==============================] - 90s 529ms/step - loss: 0.0096 - accuracy: 0.9972 - val_loss: 0.0063 - val_accuracy: 0.9981
# Epoch 44/50
# 171/171 [==============================] - 90s 529ms/step - loss: 0.0138 - accuracy: 0.9957 - val_loss: 0.0050 - val_accuracy: 0.9989
# Epoch 45/50
# 171/171 [==============================] - 90s 529ms/step - loss: 0.0093 - accuracy: 0.9976 - val_loss: 0.0079 - val_accuracy: 0.9970
# Epoch 46/50
# 171/171 [==============================] - 90s 528ms/step - loss: 0.0130 - accuracy: 0.9961 - val_loss: 0.0050 - val_accuracy: 0.9989
# Epoch 47/50
# 171/171 [==============================] - 90s 528ms/step - loss: 0.0095 - accuracy: 0.9972 - val_loss: 0.0132 - val_accuracy: 0.9956
# Epoch 48/50
# 171/171 [==============================] - 90s 529ms/step - loss: 0.0131 - accuracy: 0.9961 - val_loss: 0.0061 - val_accuracy: 0.9984
# Epoch 49/50
# 171/171 [==============================] - 90s 528ms/step - loss: 0.0114 - accuracy: 0.9960 - val_loss: 0.0044 - val_accuracy: 0.9989
# Epoch 50/50
# 171/171 [==============================] - 90s 529ms/step - loss: 0.0125 - accuracy: 0.9957 - val_loss: 0.0037 - val_accuracy: 0.9986
# c:\anaconda\envs\tqdm\lib\site-packages\tensorflow\python\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '

# %%
meta_model.evaluate(test_generator, steps=valid_steps_per_epoch)
# Out:
# 57/57 [==============================] - 25s 436ms/step - loss: 4.9835e-04 - accuracy: 1.0000
# [0.0004983519320376217, 1.0]

# %% [markdown]
# ## Training for lower amount of epochs
