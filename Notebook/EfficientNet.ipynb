# %%
import sys
sys.path.append('../')
from dataset import *
from data_aug import *
import tensorflow as tf
from comparison_model import *
from utils import *
from ranking_model import *

import random
import numpy as np
from tensorflow.keras.applications import VGG19
from tensorflow.keras.layers import Input, Dense, Flatten, BatchNormalization, Dropout, Subtract, Activation
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.applications import EfficientNetB0

# %%
image1_array, image2_array, labels = load_data("Mapillary/mapillary_training_dataaug_contrast/")
batch_size = 64

train_generator, valid_generator, test_generator, train_size, valid_size = prepare_dataset_generators(image1_array, image2_array, labels, batch_size, "comparison")

train_steps_per_epoch = train_size // batch_size
valid_steps_per_epoch = valid_size // batch_size

# %%
def comparison_siamese_model(input_shape):
    """Create a siamese model for image comparison using VGG19 as base model.

    Args:
        input_shape (tuple): Shape of the input images.
    Returns:
        keras.models.Model: The compiled siamese model.
    """
    base_model = EfficientNetB0(include_top=False, weights='imagenet')
    
    for layer in base_model.layers[:-200]:
        layer.trainable=False

    # Create inputs for pairs of images
    input_1 = Input(shape=input_shape)
    input_2 = Input(shape=input_shape)

    # Get embeddings of the images using the shared VGG19 model
    output_1 = base_model(input_1)
    output_2 = base_model(input_2)

    concat = concatenate([output_1, output_2])

    # Classification layer to predict similarity
    flatten = Flatten()(concat)
    x = Conv2D(32, (3, 3), activation="tanh", padding='same')(concat)
    x = Dropout(0.3)(x)
    x = Conv2D(32, (3, 3), activation="tanh", padding='same')(x)
    x = Dropout(0.3)(x)
    x = Flatten()(x)
    output = Dense(2, activation='sigmoid')(x)

    # Create the complete siamese model
    siamese_model = Model(inputs=[input_1, input_2], outputs=output)

    # Compile the model with the provided hyperparameters
    siamese_model.compile(loss="binary_crossentropy", optimizer=Adam(learning_rate=1e-05, decay=0.001), metrics=['accuracy'])

    # Print model summary
    siamese_model.summary()

    return siamese_model

siamese_model = comparison_siamese_model((224,224,3))
siamese_model.summary()

# %%
history = siamese_model.fit(train_generator,
          steps_per_epoch=train_steps_per_epoch,
          epochs=100,
          validation_data=valid_generator,
          validation_steps=valid_steps_per_epoch)

# %%
plot_accuracy(history)
plot_loss(history)
siamese_model.save("siamese.h5")

# %%
image1_array, image2_array, labels = load_data("Mapillary/mapillary_training_dataaug_contrast/")
batch_size = 64

train_generator, valid_generator, test_generator, train_size, valid_size = prepare_dataset_generators(image1_array, image2_array, labels, batch_size, "ranking")

train_steps_per_epoch = train_size // batch_size
valid_steps_per_epoch = valid_size // batch_size

# %%
def create_ranking_network(img_size):
    """
    Create ranking network which give a score to an image.

    :param img_size: size of input images during training
    :type img_size: tuple(int)
    :return: ranking network model
    :rtype: keras.Model
    """
    # Create feature extractor from VGG19
    feature_extractor = EfficientNetB0(include_top=False, weights='imagenet')
    for layer in feature_extractor.layers[:-200]:
        layer.trainable = False

    # Add dense layers on top of the feature extractor
    inp = Input(shape=(img_size, img_size, 3), name='input_image')
    base = feature_extractor(inp)
    base = Flatten(name='Flatten')(base)

    # Block 1
    base = Dense(32, activation='sigmoid', name='Dense_1')(base)
    base = BatchNormalization(name='BN1')(base)
    base = Dropout(0.2, name='Drop_1')(base)

    # Block 2
    base = Dense(32, activation='sigmoid', name='Dense_2')(base)
    base = BatchNormalization(name='BN2')(base)
    base = Dropout(0.2, name='Drop_2')(base)

    # Final dense
    base = Dense(1, name="Dense_Output")(base)
    base_network = Model(inp, base, name='Scoring_model')
    return base_network


def create_meta_network(img_size, weights=None):
    """
    Create meta network which is used to to teach the ranking network.

    :param img_size: dimension of input images during training.
    :type img_size: tuple(int)
    :param weights: path to the weights use for initialization
    :type weights: str
    :return: meta network model
    :rtype: keras.Model
    """

    # Create the two input branches
    input_left = Input(shape=(img_size, img_size, 3), name='left_input')
    input_right = Input(shape=(img_size, img_size, 3), name='right_input')
    base_network = create_ranking_network(img_size)
    left_score = base_network(input_left)
    right_score = base_network(input_right)

    # Subtract scores
    diff = Subtract()([left_score, right_score])

    # Pass difference through sigmoid function.
    prob = Activation("sigmoid", name="Activation_sigmoid")(diff)
    model = Model(inputs=[input_left, input_right], outputs= prob, name="Meta_Model")

    if weights:
        print('Loading weights ...')
        model.load_weights(weights)

    model.compile(optimizer=RMSprop(learning_rate=0.0001, decay=1e-05), loss="binary_crossentropy", metrics=['accuracy'])

    return model

meta_model = create_meta_network(224)

# %%
history = meta_model.fit(train_generator,
          steps_per_epoch=train_steps_per_epoch,
          epochs=100,
          validation_data=valid_generator,
          validation_steps=valid_steps_per_epoch)
# Out:
# Epoch 1/100
# 171/171 [==============================] - 106s 568ms/step - loss: 0.6588 - accuracy: 0.6938 - val_loss: 0.6592 - val_accuracy: 0.6116
# Epoch 2/100
# 171/171 [==============================] - 86s 500ms/step - loss: 0.5404 - accuracy: 0.7509 - val_loss: 0.6673 - val_accuracy: 0.6006
# Epoch 3/100
# 171/171 [==============================] - 85s 500ms/step - loss: 0.4481 - accuracy: 0.8016 - val_loss: 0.6122 - val_accuracy: 0.6782
# Epoch 4/100
# 171/171 [==============================] - 85s 498ms/step - loss: 0.3610 - accuracy: 0.8460 - val_loss: 0.6624 - val_accuracy: 0.6127
# Epoch 5/100
# 171/171 [==============================] - 85s 497ms/step - loss: 0.3147 - accuracy: 0.8658 - val_loss: 0.5321 - val_accuracy: 0.7459
# Epoch 6/100
# 171/171 [==============================] - 85s 496ms/step - loss: 0.2517 - accuracy: 0.8939 - val_loss: 0.6302 - val_accuracy: 0.7319
# Epoch 7/100
# 171/171 [==============================] - 85s 497ms/step - loss: 0.2216 - accuracy: 0.9112 - val_loss: 0.4142 - val_accuracy: 0.8095
# Epoch 8/100
# 171/171 [==============================] - 85s 496ms/step - loss: 0.1825 - accuracy: 0.9289 - val_loss: 0.4986 - val_accuracy: 0.7821
# Epoch 9/100
# 171/171 [==============================] - 85s 497ms/step - loss: 0.1645 - accuracy: 0.9326 - val_loss: 0.8078 - val_accuracy: 0.6332
# Epoch 10/100
# 171/171 [==============================] - 85s 496ms/step - loss: 0.1398 - accuracy: 0.9471 - val_loss: 0.8506 - val_accuracy: 0.5524
# Epoch 11/100
# 171/171 [==============================] - 85s 496ms/step - loss: 0.1391 - accuracy: 0.9438 - val_loss: 0.5985 - val_accuracy: 0.7059
# Epoch 12/100
# 171/171 [==============================] - 85s 498ms/step - loss: 0.1147 - accuracy: 0.9574 - val_loss: 0.2335 - val_accuracy: 0.9093
# Epoch 13/100
# 171/171 [==============================] - 85s 497ms/step - loss: 0.1028 - accuracy: 0.9610 - val_loss: 0.4218 - val_accuracy: 0.8580
# Epoch 14/100
# 171/171 [==============================] - 85s 497ms/step - loss: 0.1034 - accuracy: 0.9625 - val_loss: 0.4990 - val_accuracy: 0.8111
# Epoch 15/100
# 171/171 [==============================] - 85s 497ms/step - loss: 0.0954 - accuracy: 0.9640 - val_loss: 0.5069 - val_accuracy: 0.8150
# Epoch 16/100
# 171/171 [==============================] - 85s 496ms/step - loss: 0.0937 - accuracy: 0.9653 - val_loss: 0.3574 - val_accuracy: 0.8660
# Epoch 17/100
# 171/171 [==============================] - 85s 497ms/step - loss: 0.0855 - accuracy: 0.9673 - val_loss: 0.1001 - val_accuracy: 0.9644
# Epoch 18/100
# 171/171 [==============================] - 85s 496ms/step - loss: 0.0882 - accuracy: 0.9671 - val_loss: 0.6535 - val_accuracy: 0.7878
# Epoch 19/100
# 171/171 [==============================] - 85s 496ms/step - loss: 0.0807 - accuracy: 0.9700 - val_loss: 0.6743 - val_accuracy: 0.7281
# Epoch 20/100
# 171/171 [==============================] - 85s 496ms/step - loss: 0.0808 - accuracy: 0.9699 - val_loss: 0.0957 - val_accuracy: 0.9638
# Epoch 21/100
# 171/171 [==============================] - 85s 498ms/step - loss: 0.0699 - accuracy: 0.9748 - val_loss: 0.6236 - val_accuracy: 0.7489
# Epoch 22/100
# 171/171 [==============================] - 85s 496ms/step - loss: 0.0709 - accuracy: 0.9752 - val_loss: 0.5547 - val_accuracy: 0.7988
# Epoch 23/100
# 171/171 [==============================] - 85s 496ms/step - loss: 0.0616 - accuracy: 0.9783 - val_loss: 0.3209 - val_accuracy: 0.8914
# Epoch 24/100
# 171/171 [==============================] - 85s 496ms/step - loss: 0.0694 - accuracy: 0.9752 - val_loss: 0.3161 - val_accuracy: 0.8775
# Epoch 25/100
# 171/171 [==============================] - 85s 497ms/step - loss: 0.0607 - accuracy: 0.9771 - val_loss: 0.4925 - val_accuracy: 0.8125
# Epoch 26/100
# 171/171 [==============================] - 85s 497ms/step - loss: 0.0589 - accuracy: 0.9786 - val_loss: 0.9444 - val_accuracy: 0.5666
# Epoch 27/100
# 171/171 [==============================] - 85s 498ms/step - loss: 0.0594 - accuracy: 0.9776 - val_loss: 0.8780 - val_accuracy: 0.5789
# Epoch 28/100
# 171/171 [==============================] - 85s 496ms/step - loss: 0.0580 - accuracy: 0.9785 - val_loss: 0.5548 - val_accuracy: 0.7895
# Epoch 29/100
# 171/171 [==============================] - 85s 496ms/step - loss: 0.0518 - accuracy: 0.9825 - val_loss: 0.7110 - val_accuracy: 0.5323
# Epoch 30/100
# 171/171 [==============================] - 85s 495ms/step - loss: 0.0617 - accuracy: 0.9785 - val_loss: 0.5821 - val_accuracy: 0.8010
# Epoch 31/100
# 171/171 [==============================] - 85s 496ms/step - loss: 0.0562 - accuracy: 0.9808 - val_loss: 0.3013 - val_accuracy: 0.8942
# Epoch 32/100
# 171/171 [==============================] - 85s 496ms/step - loss: 0.0545 - accuracy: 0.9797 - val_loss: 0.8817 - val_accuracy: 0.6842
# Epoch 33/100
# 171/171 [==============================] - 85s 497ms/step - loss: 0.0542 - accuracy: 0.9814 - val_loss: 0.7834 - val_accuracy: 0.5935
# Epoch 34/100
# 171/171 [==============================] - 85s 498ms/step - loss: 0.0571 - accuracy: 0.9802 - val_loss: 0.6013 - val_accuracy: 0.8015
# Epoch 35/100
# 171/171 [==============================] - 85s 496ms/step - loss: 0.0554 - accuracy: 0.9803 - val_loss: 0.6873 - val_accuracy: 0.5757
# Epoch 36/100
# 171/171 [==============================] - 85s 496ms/step - loss: 0.0531 - accuracy: 0.9810 - val_loss: 0.4754 - val_accuracy: 0.8459
# Epoch 37/100
# 171/171 [==============================] - 85s 496ms/step - loss: 0.0499 - accuracy: 0.9831 - val_loss: 0.6357 - val_accuracy: 0.7876
# Epoch 38/100
# 171/171 [==============================] - 85s 496ms/step - loss: 0.0522 - accuracy: 0.9826 - val_loss: 0.8080 - val_accuracy: 0.6042
# Epoch 39/100
# 171/171 [==============================] - 85s 496ms/step - loss: 0.0541 - accuracy: 0.9808 - val_loss: 0.7741 - val_accuracy: 0.6017
# Epoch 40/100
# 171/171 [==============================] - 85s 496ms/step - loss: 0.0516 - accuracy: 0.9827 - val_loss: 0.6633 - val_accuracy: 0.6930
# Epoch 41/100
# 171/171 [==============================] - 85s 495ms/step - loss: 0.0511 - accuracy: 0.9816 - val_loss: 0.8277 - val_accuracy: 0.7338
# Epoch 42/100
# 171/171 [==============================] - 85s 496ms/step - loss: 0.0473 - accuracy: 0.9830 - val_loss: 0.8687 - val_accuracy: 0.7119
# Epoch 43/100
# 171/171 [==============================] - 85s 496ms/step - loss: 0.0411 - accuracy: 0.9853 - val_loss: 0.1351 - val_accuracy: 0.9435
# Epoch 44/100
# 171/171 [==============================] - 85s 495ms/step - loss: 0.0470 - accuracy: 0.9832 - val_loss: 0.2587 - val_accuracy: 0.9101
# Epoch 45/100
# 171/171 [==============================] - 85s 495ms/step - loss: 0.0440 - accuracy: 0.9843 - val_loss: 0.5895 - val_accuracy: 0.7610
# Epoch 46/100
# 171/171 [==============================] - 85s 496ms/step - loss: 0.0438 - accuracy: 0.9850 - val_loss: 0.3848 - val_accuracy: 0.8747
# Epoch 47/100
# 171/171 [==============================] - 85s 495ms/step - loss: 0.0475 - accuracy: 0.9848 - val_loss: 0.0450 - val_accuracy: 0.9822
# Epoch 48/100
# 171/171 [==============================] - 85s 495ms/step - loss: 0.0424 - accuracy: 0.9850 - val_loss: 0.6343 - val_accuracy: 0.7495
# Epoch 49/100
# 171/171 [==============================] - 85s 496ms/step - loss: 0.0434 - accuracy: 0.9847 - val_loss: 0.6813 - val_accuracy: 0.5661
# Epoch 50/100
# 171/171 [==============================] - 85s 496ms/step - loss: 0.0383 - accuracy: 0.9885 - val_loss: 0.4205 - val_accuracy: 0.8736
# Epoch 51/100
# 171/171 [==============================] - 85s 496ms/step - loss: 0.0509 - accuracy: 0.9837 - val_loss: 0.1200 - val_accuracy: 0.9556
# Epoch 52/100
# 171/171 [==============================] - 85s 496ms/step - loss: 0.0437 - accuracy: 0.9841 - val_loss: 0.7980 - val_accuracy: 0.4811
# Epoch 53/100
# 171/171 [==============================] - 85s 496ms/step - loss: 0.0478 - accuracy: 0.9829 - val_loss: 0.4946 - val_accuracy: 0.8237
# Epoch 54/100
# 171/171 [==============================] - 85s 495ms/step - loss: 0.0418 - accuracy: 0.9866 - val_loss: 0.7345 - val_accuracy: 0.6510
# Epoch 55/100
# 171/171 [==============================] - 85s 495ms/step - loss: 0.0402 - accuracy: 0.9862 - val_loss: 0.8259 - val_accuracy: 0.5773
# Epoch 56/100
# 171/171 [==============================] - 85s 496ms/step - loss: 0.0393 - accuracy: 0.9850 - val_loss: 0.7747 - val_accuracy: 0.6842
# Epoch 57/100
# 171/171 [==============================] - 85s 495ms/step - loss: 0.0412 - accuracy: 0.9858 - val_loss: 0.7494 - val_accuracy: 0.7736
# Epoch 58/100
# 171/171 [==============================] - 85s 495ms/step - loss: 0.0379 - accuracy: 0.9872 - val_loss: 0.4362 - val_accuracy: 0.8569
# Epoch 59/100
# 171/171 [==============================] - 85s 496ms/step - loss: 0.0407 - accuracy: 0.9861 - val_loss: 0.0788 - val_accuracy: 0.9704
# Epoch 60/100
# 171/171 [==============================] - 85s 495ms/step - loss: 0.0425 - accuracy: 0.9843 - val_loss: 0.6663 - val_accuracy: 0.6107
# Epoch 61/100
# 171/171 [==============================] - 85s 495ms/step - loss: 0.0375 - accuracy: 0.9871 - val_loss: 0.7707 - val_accuracy: 0.6541
# Epoch 62/100
# 171/171 [==============================] - 85s 495ms/step - loss: 0.0411 - accuracy: 0.9847 - val_loss: 1.2568 - val_accuracy: 0.7018
# Epoch 63/100
# 171/171 [==============================] - 85s 495ms/step - loss: 0.0400 - accuracy: 0.9852 - val_loss: 0.8383 - val_accuracy: 0.6623
# Epoch 64/100
# 171/171 [==============================] - 85s 495ms/step - loss: 0.0388 - accuracy: 0.9866 - val_loss: 0.1376 - val_accuracy: 0.9548
# Epoch 65/100
# 171/171 [==============================] - 85s 495ms/step - loss: 0.0430 - accuracy: 0.9865 - val_loss: 0.5729 - val_accuracy: 0.7730
# Epoch 66/100
# 171/171 [==============================] - 85s 495ms/step - loss: 0.0398 - accuracy: 0.9871 - val_loss: 0.6376 - val_accuracy: 0.7092
# Epoch 67/100
# 171/171 [==============================] - 85s 495ms/step - loss: 0.0367 - accuracy: 0.9862 - val_loss: 0.0861 - val_accuracy: 0.9677
# Epoch 68/100
# 171/171 [==============================] - 85s 496ms/step - loss: 0.0375 - accuracy: 0.9870 - val_loss: 0.6280 - val_accuracy: 0.7640
# Epoch 69/100
# 171/171 [==============================] - 85s 495ms/step - loss: 0.0332 - accuracy: 0.9892 - val_loss: 0.5677 - val_accuracy: 0.7966
# Epoch 70/100
# 171/171 [==============================] - 85s 496ms/step - loss: 0.0344 - accuracy: 0.9880 - val_loss: 0.7743 - val_accuracy: 0.7505
# Epoch 71/100
# 171/171 [==============================] - 85s 495ms/step - loss: 0.0387 - accuracy: 0.9871 - val_loss: 0.7298 - val_accuracy: 0.7555
# Epoch 72/100
# 171/171 [==============================] - 85s 495ms/step - loss: 0.0342 - accuracy: 0.9876 - val_loss: 0.2790 - val_accuracy: 0.9065
# Epoch 73/100
# 171/171 [==============================] - 85s 495ms/step - loss: 0.0381 - accuracy: 0.9867 - val_loss: 0.4685 - val_accuracy: 0.8410
# Epoch 74/100
# 171/171 [==============================] - 85s 495ms/step - loss: 0.0351 - accuracy: 0.9869 - val_loss: 0.3789 - val_accuracy: 0.8731
# Epoch 75/100
# 171/171 [==============================] - 85s 495ms/step - loss: 0.0352 - accuracy: 0.9881 - val_loss: 0.8262 - val_accuracy: 0.5496
# Epoch 76/100
# 171/171 [==============================] - 85s 495ms/step - loss: 0.0363 - accuracy: 0.9883 - val_loss: 0.7314 - val_accuracy: 0.7179
# Epoch 77/100
# 171/171 [==============================] - 85s 495ms/step - loss: 0.0333 - accuracy: 0.9879 - val_loss: 0.8308 - val_accuracy: 0.7133
# Epoch 78/100
# 171/171 [==============================] - 85s 496ms/step - loss: 0.0386 - accuracy: 0.9858 - val_loss: 0.2974 - val_accuracy: 0.8988
# Epoch 79/100
# 171/171 [==============================] - 85s 495ms/step - loss: 0.0330 - accuracy: 0.9900 - val_loss: 0.7966 - val_accuracy: 0.7048
# Epoch 80/100
# 171/171 [==============================] - 85s 496ms/step - loss: 0.0346 - accuracy: 0.9884 - val_loss: 0.7414 - val_accuracy: 0.6530
# Epoch 81/100
# 171/171 [==============================] - 85s 495ms/step - loss: 0.0389 - accuracy: 0.9859 - val_loss: 0.4852 - val_accuracy: 0.7837
# Epoch 82/100
# 171/171 [==============================] - 85s 495ms/step - loss: 0.0377 - accuracy: 0.9865 - val_loss: 0.4727 - val_accuracy: 0.8311
# Epoch 83/100
# 171/171 [==============================] - 85s 495ms/step - loss: 0.0376 - accuracy: 0.9879 - val_loss: 0.2344 - val_accuracy: 0.9178
# Epoch 84/100
# 171/171 [==============================] - 85s 495ms/step - loss: 0.0333 - accuracy: 0.9873 - val_loss: 0.1285 - val_accuracy: 0.9523
# Epoch 85/100
# 171/171 [==============================] - 85s 495ms/step - loss: 0.0365 - accuracy: 0.9868 - val_loss: 0.4672 - val_accuracy: 0.8130
# Epoch 86/100
# 171/171 [==============================] - 85s 495ms/step - loss: 0.0372 - accuracy: 0.9868 - val_loss: 0.3659 - val_accuracy: 0.8766
# Epoch 87/100
# 171/171 [==============================] - 85s 496ms/step - loss: 0.0280 - accuracy: 0.9906 - val_loss: 0.3703 - val_accuracy: 0.8706
# Epoch 88/100
# 171/171 [==============================] - 85s 496ms/step - loss: 0.0345 - accuracy: 0.9888 - val_loss: 0.3959 - val_accuracy: 0.8309
# Epoch 89/100
# 171/171 [==============================] - 85s 495ms/step - loss: 0.0347 - accuracy: 0.9885 - val_loss: 0.5759 - val_accuracy: 0.8152
# Epoch 90/100
# 171/171 [==============================] - 85s 496ms/step - loss: 0.0338 - accuracy: 0.9882 - val_loss: 0.3169 - val_accuracy: 0.8819
# Epoch 91/100
# 171/171 [==============================] - 85s 495ms/step - loss: 0.0328 - accuracy: 0.9904 - val_loss: 0.1464 - val_accuracy: 0.9509
# Epoch 92/100
# 171/171 [==============================] - 85s 495ms/step - loss: 0.0327 - accuracy: 0.9900 - val_loss: 0.8638 - val_accuracy: 0.5312
# Epoch 93/100
# 171/171 [==============================] - 85s 494ms/step - loss: 0.0370 - accuracy: 0.9880 - val_loss: 0.1894 - val_accuracy: 0.9298
# Epoch 94/100
# 171/171 [==============================] - 85s 499ms/step - loss: 0.0290 - accuracy: 0.9898 - val_loss: 0.3048 - val_accuracy: 0.8887
# Epoch 95/100
# 171/171 [==============================] - 85s 499ms/step - loss: 0.0355 - accuracy: 0.9874 - val_loss: 0.2610 - val_accuracy: 0.9084
# Epoch 96/100
# 171/171 [==============================] - 85s 499ms/step - loss: 0.0382 - accuracy: 0.9876 - val_loss: 0.8939 - val_accuracy: 0.7475
# Epoch 97/100
# 171/171 [==============================] - 85s 498ms/step - loss: 0.0275 - accuracy: 0.9906 - val_loss: 0.4681 - val_accuracy: 0.8070
# Epoch 98/100
# 171/171 [==============================] - 85s 496ms/step - loss: 0.0327 - accuracy: 0.9894 - val_loss: 0.4650 - val_accuracy: 0.8470
# Epoch 99/100
# 171/171 [==============================] - 85s 495ms/step - loss: 0.0335 - accuracy: 0.9888 - val_loss: 0.0314 - val_accuracy: 0.9888
# Epoch 100/100
# 171/171 [==============================] - 85s 496ms/step - loss: 0.0318 - accuracy: 0.9887 - val_loss: 0.9324 - val_accuracy: 0.6338

# %%
meta_model.save("meta_model_weight.h5")
ranking_model = meta_model.get_layer('Scoring_model')
ranking_model.save_weights('ranking_model_weights.h5')
plot_loss(history)
plot_accuracy(history)
# Out:
# c:\anaconda\envs\tqdm\lib\site-packages\tensorflow\python\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
